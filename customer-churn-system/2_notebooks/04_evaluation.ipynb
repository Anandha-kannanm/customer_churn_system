# %% [markdown]
# # 04 — Model Evaluation

# %%
import json
from pathlib import Path

metrics = json.load(open(Path('..') / '5_model' / 'model_metrics.json'))
print(f"Accuracy: {metrics['accuracy']}")
print(f"ROC-AUC: {metrics['roc_auc']}")
